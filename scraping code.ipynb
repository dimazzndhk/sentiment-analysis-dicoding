# %% [markdown]
# Scraping Review Aplikasi MyPertamina
# ---

# %%
pip install google_play_scraper
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google_play_scraper import app, Sort, reviews
import pandas as pd
import numpy as np

# %% [markdown]
# scraping akan dilakukan untuk mengambil 15000 data review aplikasi MyPertamina

# %%
scrapreview, _ = reviews(
    'com.dafturn.mypertamina',
    lang='id',
    country='id',
    count=15000
)

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_aplikasi_pertamina.csv', index=False)
 
# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)
 
# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
app_reviews_df
# Out:
#                                    reviewId         userName  \
# 0      bfc59f6b-138f-48d5-8e6d-6ea89a686ae7  Pengguna Google
# 1      04748ba4-d9ea-4894-a5aa-5029cf5b6a5f  Pengguna Google
# 2      b50b2111-e996-4157-b57e-08d350b13c43  Pengguna Google
# 3      d88492d6-8ad2-433e-be70-83112483c0cd  Pengguna Google
# 4      74e75193-f7f8-4a99-be66-bb38bb2626ed  Pengguna Google
# ...                                     ...              ...
# 14995  402a356a-10cc-4d69-9d50-ddbe8bbc34d6         Rokhadin
# 14996  a080f6eb-4528-4a79-a7a4-adc072bd699c     ahmad gozali
# 14997  7bd7f5d2-52b7-445b-958b-7a93a5c2d3cf        Apo Ricky
# 14998  56d65eb1-102a-463a-aa4d-913ab1787109       Baiq Erika
# 14999  e3b2c09d-9622-4561-b6c8-2e41c8717790  Hanik Apriliani
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %% [markdown]
# Selanjutnya, akan dilakukan pengecekan dari hasil scraping sebagai berikut.

# %%
app_reviews_df['score'].value_counts()
# Out:
# score
# 1    7322
# 5    5597
# 2     736
# 4     684
# 3     661
# Name: count, dtype: int64

# %% [markdown]
# Akan dilakukan pengecekan apakah terdapat nilai duplikat dari hasil scraping dan diperoleh tidak terdapat nilai duplikat.

# %%
app_reviews_df.duplicated().value_counts()
# Out:
# False    15000
# Name: count, dtype: int64

# %% [markdown]
# Akan dilakukan juga pengecekan apakah terdapat missing value pada hasil scraping.

# %%
app_reviews_df.isna().sum()
# Out:
# reviewId                   0
# userName                   0
# userImage                  0
# content                    0
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion    2465
# at                         0
# replyContent            9484
# repliedAt               9484
# appVersion              2465
# dtype: int64

# %% [markdown]
# Diperoleh terdapat missing values pada beberapa variabel. Penanganan missing values akan dipertimbangkan pada saat proses analisis.
